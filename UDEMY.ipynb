# %%
import pandas as pd

# %%
data=pd.read_csv(r'D:\STUDY\PYTHON\big data practice\7. Udemy Courses.csv')

# %%
data
# Out:
#       course_id                                       course_title  is_paid  \
# 0        288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1       1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2       1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3       1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4       1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
# ...         ...                                                ...      ...
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
# ...

# %%
data.dtypes
# Out:
# course_id               int64
# course_title           object
# is_paid                  bool
# price                  object
# num_subscribers         int64
# num_reviews             int64
# num_lectures            int64
# level                  object
# content_duration       object
# published_timestamp    object
# subject                object
# dtype: object

# %%
data.info
# Out:
# <bound method DataFrame.info of       course_id                                       course_title  is_paid  \
# 0        288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1       1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2       1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3       1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4       1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
# ...         ...                                                ...      ...
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
# ...

# %%
data.shape
# Out:
# (3682, 11)

# %%
data.head()
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
# 2    75              482            1            47  Intermediate Level
# 3    75              850            3            43  Intermediate Level
# 4    75              940            3            32  Intermediate Level
#
#   content_duration   published_timestamp              subject
# ...

# %%
data.head(30)
# Out:
#     course_id                                       course_title  is_paid  \
# 0      288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1     1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2     1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3     1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4     1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
# 5     1122832  #6 Piano Hand Coordination: Play Open 10 Balla...     True
# 6     1123184  #7 Piano Hand Coordination: Play Piano Runs in...     True
# 7      768028  * An Integrated Approach to the Fundamentals o...     True
# 8      206592  :::Beginners Guide To Creating Amazing Images ...     True
# 9      738910  [Value Investing] Where White People Keep Thei...     True
# 10     591880  1 - Concepts of Statistics For Beginners Step ...     True
# 11      64605                                         1 Hour CSS     True
# ...

# %%
data.tail()
# Out:
#       course_id                                       course_title  is_paid  \
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
#      price  num_subscribers  num_reviews  num_lectures           level  \
# 3677   120             1566           29            36      All Levels
# 3678    70             1018           12            22  Beginner Level
# 3679    40              723          130            37      All Levels
# 3680  Free              229            0            33      All Levels
# 3681    50               12            1            15      All Levels
#
#      content_duration   published_timestamp              subject
# ...

# %%
data.tail(46)
# Out:
#       course_id                                       course_title  is_paid  \
# 3636    1236746                          WordPress Tips and Tricks     True
# 3637     361620                              Wordpress Tutorial        True
# 3638    1068590                     Wordpress Website Mastery 2017    False
# 3639    1122306         Wordpress: Comment utiliser le thème FABLE     True
# 3640     774910     WordPress: Create an Amazing Website With Ease     True
# 3641     941990  Work From Home Online (Part/Full) : Trade Fore...     True
# 3642    1153854  Working Capital assessment for bankers, credit...     True
# 3643     326948  Working Capital Management for CA / CFA / CPA ...     True
# 3644     221872       Working Capital Management for Entrepreneurs     True
# 3645    1271430        Workshop on Banking Credit Analysis Process     True
# 3646    1003250    World Percussion: Complete Lessons for Everyone     True
# ...

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'is_paid', 'price', 'num_subscribers',
#        'num_reviews', 'num_lectures', 'level', 'content_duration',
#        'published_timestamp', 'subject'],
#       dtype='object')

# %%
data['course_id'].nunique()
# Out:
# 3676

# %%
data['course_title'].nunique()
# Out:
# 3667

# %%
data.nunique()
# Out:
# course_id              3676
# course_title           3667
# is_paid                   2
# price                    38
# num_subscribers        2198
# num_reviews             511
# num_lectures            229
# level                     4
# content_duration        109
# published_timestamp    3676
# subject                   4
# dtype: int64

# %%
data['course_title'].value_counts()
# Out:
# Acoustic Blues Guitar Lessons                             3
# Creating an animated greeting card via Google Slides      3
# Drum Lessons For Beginners                                2
# How to Make a Wordpress Website 2017                      2
# Aprende a tocar el acordeón de botones                    2
#                                                          ..
# Financial analysis: Compare performance of companies      1
# Financial and Business Simulation with Microsoft Excel    1
# Financial Management - A Complete Study                   1
# Financial Management - Ratio Analysis                     1
# Zombie Apocalypse Photoshop Actions                       1
# Name: course_title, Length: 3667, dtype: int64

# %%
data['subject'].value_counts()
# Out:
# Web Development        1200
# Business Finance       1199
# Musical Instruments     680
# Graphic Design          603
# Name: subject, dtype: int64

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'is_paid', 'price', 'num_subscribers',
#        'num_reviews', 'num_lectures', 'level', 'content_duration',
#        'published_timestamp', 'subject'],
#       dtype='object')

# %%
data.columns
print(data[['course_id','course_title','subject']])
# Out:
#       course_id                                       course_title  \
# 0        288942  #1 Piano Hand Coordination: Play 10th Ballad i...
# 1       1170074  #10 Hand Coordination - Transfer Chord Ballad ...
# 2       1193886  #12 Hand Coordination: Let your Hands dance wi...
# 3       1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...
# 4       1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...
# ...         ...                                                ...
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...
# 3678     552700    Your Second Course on Piano: Two Handed Playing
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...
# 3681     964478                Zombie Apocalypse Photoshop Actions
#
#                   subject
# 0     Musical Instruments
# 1     Musical Instruments
# 2     Musical Instruments
# 3     Musical Instruments
# ...

# %%
data.head()
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
# 2    75              482            1            47  Intermediate Level
# 3    75              850            3            43  Intermediate Level
# 4    75              940            3            32  Intermediate Level
#
#   content_duration   published_timestamp              subject
# ...

# %%
data.subject.value_counts()
# Out:
# Web Development        1200
# Business Finance       1199
# Musical Instruments     680
# Graphic Design          603
# Name: subject, dtype: int64

# %%
data[data.subject=='Web Development']
# Out:
#       course_id                                       course_title  is_paid  \
# 11        64605                                         1 Hour CSS     True
# 12        64422                                        1 Hour HTML     True
# 13        63612                                  1 Hour JavaScript     True
# 14        72262                                      1 hour jQuery     True
# 24       975916  17 Complete JavaScript   projects explained st...     True
# ...         ...                                                ...      ...
# 3666     969170                          XSD :basics for beginners     True
# 3667     968278                         XSLT :basics for beginners     True
# 3670     560996  You can create Incredible Websites with HTML C...     True
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
#
# ...

# %%
data.groupby('subject').get_group('Web Development')
# Out:
#       course_id                                       course_title  is_paid  \
# 11        64605                                         1 Hour CSS     True
# 12        64422                                        1 Hour HTML     True
# 13        63612                                  1 Hour JavaScript     True
# 14        72262                                      1 hour jQuery     True
# 24       975916  17 Complete JavaScript   projects explained st...     True
# ...         ...                                                ...      ...
# 3666     969170                          XSD :basics for beginners     True
# 3667     968278                         XSLT :basics for beginners     True
# 3670     560996  You can create Incredible Websites with HTML C...     True
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
#
# ...

# %%
data
# Out:
#       course_id                                       course_title  is_paid  \
# 0        288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1       1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2       1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3       1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4       1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
# ...         ...                                                ...      ...
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
# ...

# %%
data.subject.unique()
# Out:
# array(['Musical Instruments', 'Business Finance', 'Graphic Design',
#        'Web Development'], dtype=object)

# %%
data.subject.value_counts()
# Out:
# Web Development        1200
# Business Finance       1199
# Musical Instruments     680
# Graphic Design          603
# Name: subject, dtype: int64

# %%
data.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1           1 hour  2017-04-12T19:06:34Z  Musical Instruments

# %%
#Show all the courses which are Paid

# %%
data
# Out:
#       course_id                                       course_title  is_paid  \
# 0        288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1       1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2       1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3       1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4       1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
# ...         ...                                                ...      ...
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
# ...

# %%
data
# Out:
#       course_id                                       course_title  is_paid  \
# 0        288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1       1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2       1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3       1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4       1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
# ...         ...                                                ...      ...
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
# ...

# %%
data.is_paid.value_counts()
# Out:
# True     3372
# False     310
# Name: is_paid, dtype: int64

# %%
data.dtypes
# Out:
# course_id               int64
# course_title           object
# is_paid                  bool
# price                  object
# num_subscribers         int64
# num_reviews             int64
# num_lectures            int64
# level                  object
# content_duration       object
# published_timestamp    object
# subject                object
# dtype: object

# %%
data.price.unique()
# Out:
# array(['35', '75', '65', '200', '25', '100', '20', '40', '30', '45',
#        '185', '120', '105', '50', 'Free', '145', '55', '85', '110', '150',
#        '95', '180', '125', '60', '90', '195', '80', '70', '140', '190',
#        '115', '130', '170', '175', '165', '135', '155', '160'],
#       dtype=object)

# %%
data.price.value_counts()
# Out:
# 20      830
# 50      468
# Free    310
# 200     295
# 40      217
# 30      170
# 25      154
# 95      152
# 100     133
# 195     127
# 35      116
# 150      88
# 45       83
# 75       81
# 60       75
# 120      37
# 55       35
# 85       31
# 65       30
# 125      30
# 80       29
# 145      27
# 70       26
# 90       19
# 180      17
# 115      16
# 175      13
# 105      11
# 140      10
# 190      10
# 110       8
# 135       8
# 185       6
# 165       6
# 170       5
# 160       4
# 130       3
# 155       2
# Name: price, dtype: int64

# %%
data[data.price=='Free']
# Out:
#       course_id                                       course_title  is_paid  \
# 41       286070        5 lecciones que todo guitarrista debe tomar    False
# 49       696630  7 Ways A Beginner Guitarist Can Sound Better, ...    False
# 57       955914  A beginner`s guide to fingerpicking and strumm...    False
# 67       270976                             A how to guide in HTML    False
# 74      1214144  ¡Triunfar en La Bolsa de Valores No Requiere d...    False
# ...         ...                                                ...      ...
# 3620     552598  WordPress in under an hour - Create/manage you...    False
# 3638    1068590                     Wordpress Website Mastery 2017    False
# 3652     752706  Write quicker HTML5 and CSS 3; productivity ha...    False
# 3674    1257976  Your First 10 Guitar Lessons - Learn how to pl...    False
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
#
# ...

# %%
da
